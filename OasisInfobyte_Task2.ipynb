# %% [markdown]
# #Unempoyment in India Data Analysis

# %%
#importing all the needed libraries and modules
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("Unemployment in India.csv")
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %% [markdown]
# ####Exploring Dataset

# %%
df.head(10)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5  Andhra Pradesh   31-10-2019    Monthly                              3.52
# 6  Andhra Pradesh   30-11-2019    Monthly                              4.12
# 7  Andhra Pradesh   31-12-2019    Monthly                              4.38
# 8  Andhra Pradesh   31-01-2020    Monthly                              4.84
# 9  Andhra Pradesh   29-02-2020    Monthly                              5.91
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# ...

# %%
df.tail(10)
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 758    NaN   NaN        NaN                               NaN
# 759    NaN   NaN        NaN                               NaN
# 760    NaN   NaN        NaN                               NaN
# 761    NaN   NaN        NaN                               NaN
# 762    NaN   NaN        NaN                               NaN
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 758                  NaN                                       NaN  NaN
# 759                  NaN                                       NaN  NaN
# ...

# %%
df.iloc[60:70]
# Out:
#    Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 60  Delhi   30-11-2019    Monthly                             11.11
# 61  Delhi   31-12-2019    Monthly                             16.97
# 62  Delhi   31-01-2020    Monthly                             13.48
# 63  Delhi   29-02-2020    Monthly                             13.81
# 64  Delhi   31-03-2020    Monthly                             15.18
# 65  Delhi   30-04-2020    Monthly                             20.69
# 66  Delhi   31-05-2020    Monthly                             22.76
# 67  Delhi   30-06-2020    Monthly                             21.14
# 68    Goa   31-05-2019    Monthly                              2.91
# 69    Goa   30-06-2019    Monthly                              5.45
#
#      Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 60             178768.0                                     42.71  Rural
# 61             145671.0                                     37.08  Rural
# ...

# %%
df.shape
# Out:
# (768, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.isna().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %% [markdown]
# ####Dealing with null values

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
df.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
# renaming columns
df.columns=['Region', 'Date', 'Frequency', 'Est Unemployment Rate', 'Est Employed', 'Est Labour Participation Rate', 'Area']
df
# Out:
#              Region         Date Frequency  Est Unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019   Monthly                   3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                   3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                   3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                   3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                   5.17
# ..              ...          ...       ...                    ...
# 749     West Bengal   29-02-2020   Monthly                   7.55
# 750     West Bengal   31-03-2020   Monthly                   6.67
# 751     West Bengal   30-04-2020   Monthly                  15.63
# 752     West Bengal   31-05-2020   Monthly                  15.22
# 753     West Bengal   30-06-2020   Monthly                   9.86
#
#      Est Employed  Est Labour Participation Rate   Area
# 0      11999139.0                          43.24  Rural
# 1      11755881.0                          42.05  Rural
# ...

# %%
df['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %%
# to see what kinds of information we can extract from given data
print("The region most data of unemployment rate is available for:-")
print(df['Region'].value_counts().idxmax())
# Out:
# The region most data of unemployment rate is available for:-
# Andhra Pradesh

# %% [markdown]
# ####Visualization

# %%
region_unemployment_sum = df.groupby('Region')['Est Unemployment Rate'].sum()
plt.figure(figsize=(8,10))
plt.pie(region_unemployment_sum, labels=region_unemployment_sum.index, autopct='%1.1f%%', startangle=140)
plt.title("Unemployment Rate based on Region")
plt.show()

# %%
plt.figure(figsize=(8,10))
area=df['Area'].value_counts()
plt.pie(area, labels=area.index, autopct='%1.1f%%', startangle=140)
plt.title("Unemployment Rate based on Area")
plt.show()

# %%
# as unemployment rate based on monthly basis can be an important information adding a column of month

import datetime as dt
import calendar

df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df['month'] =  df['Date'].dt.month

df['Month'] =  df['month'].apply(lambda x: calendar.month_abbr[x])
# Out:
# <ipython-input-49-c907979faa1a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
# <ipython-input-49-c907979faa1a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] =  df['Date'].dt.month
# <ipython-input-49-c907979faa1a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#              Region       Date Frequency  Est Unemployment Rate  Est Employed  \
# 0    Andhra Pradesh 2019-05-31   Monthly                   3.65    11999139.0
# 1    Andhra Pradesh 2019-06-30   Monthly                   3.05    11755881.0
# 2    Andhra Pradesh 2019-07-31   Monthly                   3.75    12086707.0
# 3    Andhra Pradesh 2019-08-31   Monthly                   3.32    12285693.0
# 4    Andhra Pradesh 2019-09-30   Monthly                   5.17    12256762.0
# ..              ...        ...       ...                    ...           ...
# 749     West Bengal 2020-02-29   Monthly                   7.55    10871168.0
# 750     West Bengal 2020-03-31   Monthly                   6.67    10806105.0
# 751     West Bengal 2020-04-30   Monthly                  15.63     9299466.0
# 752     West Bengal 2020-05-31   Monthly                  15.22     9240903.0
# 753     West Bengal 2020-06-30   Monthly                   9.86     9088931.0
#
# ...

# %%
# as they both don't serve any unique information
df=df.drop(['Frequency', 'month'], axis=1)
df
# Out:
#              Region       Date  Est Unemployment Rate  Est Employed  \
# 0    Andhra Pradesh 2019-05-31                   3.65    11999139.0
# 1    Andhra Pradesh 2019-06-30                   3.05    11755881.0
# 2    Andhra Pradesh 2019-07-31                   3.75    12086707.0
# 3    Andhra Pradesh 2019-08-31                   3.32    12285693.0
# 4    Andhra Pradesh 2019-09-30                   5.17    12256762.0
# ..              ...        ...                    ...           ...
# 749     West Bengal 2020-02-29                   7.55    10871168.0
# 750     West Bengal 2020-03-31                   6.67    10806105.0
# 751     West Bengal 2020-04-30                  15.63     9299466.0
# 752     West Bengal 2020-05-31                  15.22     9240903.0
# 753     West Bengal 2020-06-30                   9.86     9088931.0
#
#      Est Labour Participation Rate   Area Month
# 0                            43.24  Rural   May
# 1                            42.05  Rural   Jun
# ...

# %%
print("The month most data of unemployment rate is available for:-")
print(df['Month'].value_counts().idxmax())
# Out:
# The month most data of unemployment rate is available for:-
# May

# %%
month_unemployment_sum = df.groupby('Month')['Est Unemployment Rate'].sum()
plt.figure(figsize=(8,10))
plt.pie(month_unemployment_sum, labels=month_unemployment_sum.index, autopct='%1.1f%%', startangle=140)
plt.title("Unemployment Rate based on Month")
plt.show()

# %%
plt.figure(figsize=(10,12))
plt.title('Unemployment Rate In India State Wise')
sns.histplot(x='Est Unemployment Rate', hue="Region", data=df)
plt.show()

# %% [markdown]
# ####Encoding and Standardizing Data so it can be used for Training Purpose

# %%
labelEncode = LabelEncoder()
df['Area'] = labelEncode.fit_transform(df['Area'])

df
# Out:
#              Region       Date  Est Unemployment Rate  Est Employed  \
# 0    Andhra Pradesh 2019-05-31                   3.65    11999139.0
# 1    Andhra Pradesh 2019-06-30                   3.05    11755881.0
# 2    Andhra Pradesh 2019-07-31                   3.75    12086707.0
# 3    Andhra Pradesh 2019-08-31                   3.32    12285693.0
# 4    Andhra Pradesh 2019-09-30                   5.17    12256762.0
# ..              ...        ...                    ...           ...
# 749     West Bengal 2020-02-29                   7.55    10871168.0
# 750     West Bengal 2020-03-31                   6.67    10806105.0
# 751     West Bengal 2020-04-30                  15.63     9299466.0
# 752     West Bengal 2020-05-31                  15.22     9240903.0
# 753     West Bengal 2020-06-30                   9.86     9088931.0
#
#      Est Labour Participation Rate  Area Month
# 0                            43.24     0   May
# 1                            42.05     0   Jun
# ...

# %%
columns_to_standardize = ['Est Unemployment Rate', 'Est Employed', 'Est Labour Participation Rate']

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit and transform the selected columns
df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])

# %%
df
# Out:
#              Region       Date  Est Unemployment Rate  Est Employed  \
# 0    Andhra Pradesh 2019-05-31              -0.759558      0.593216
# 1    Andhra Pradesh 2019-06-30              -0.815559      0.563119
# 2    Andhra Pradesh 2019-07-31              -0.750225      0.604050
# 3    Andhra Pradesh 2019-08-31              -0.790359      0.628669
# 4    Andhra Pradesh 2019-09-30              -0.617688      0.625090
# ..              ...        ...                    ...           ...
# 749     West Bengal 2020-02-29              -0.395550      0.453659
# 750     West Bengal 2020-03-31              -0.477685      0.445609
# 751     West Bengal 2020-04-30               0.358600      0.259202
# 752     West Bengal 2020-05-31               0.320332      0.251956
# 753     West Bengal 2020-06-30              -0.179946      0.233154
#
#      Est Labour Participation Rate  Area Month
# 0                         0.075241     0   May
# 1                        -0.071570     0   Jun
# ...

# %% [markdown]
# This cleaned dataset can be used to extract information for various questions and training purposes.
